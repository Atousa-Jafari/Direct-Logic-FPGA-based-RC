# %%
def run_esn_quantization(N, bit_width):
    from reservoirpy.datasets import multiscroll
    from reservoirpy.nodes import Reservoir, Ridge
    from reservoirpy.observables import rmse, rsquare, nrmse
    from brevitas.nn import QuantIdentity
    import numpy as np
    import torch
    from reservoirpy import Node

    # Prepare Lorenz dataset
    X = multiscroll(10000)
    X = 2 * (X - X.min()) / (X.max() - X.min()) - 1

    train_len = 5000
    threshold_scale = 1.0 / (2 ** bit_width) 

    # Initialize and train ESN (FP32)
    reservoir = Reservoir(N, lr=1, sr=0.9, input_connectivity=0.9, rc_connectivity=0.1, input_scaling=1)
    readout = Ridge(ridge=1e-2)
    esn_model = reservoir >> readout
    esn_model = esn_model.fit(X[:train_len], X[1:train_len + 1], warmup=1000)

    # Quantization helper
    def extract_Qinput(input_array, num_bits):
        quant_identity = QuantIdentity(return_quant_tensor=True, bit_width=num_bits)
        float_input = torch.tensor(input_array, dtype=torch.float64)
        quant_input = quant_identity(float_input)
        return (
            quant_input.int().detach().numpy(),
            quant_input.scale.detach().numpy(),
            quant_input.zero_point.detach().numpy()
        )

    # Extract quantized versions
    int_x, x_scale, _ = extract_Qinput(X, num_bits=bit_width)
    int_Win, scale_Win, _ = extract_Qinput(esn_model.nodes[0].Win.todense(), num_bits=bit_width)
    int_Wr, scale_Wr, _ = extract_Qinput(esn_model.nodes[0].W.todense(), num_bits=bit_width)
    int_bias, _, _ = extract_Qinput(esn_model.nodes[0].bias.todense(), num_bits=bit_width)

    input_scale = (scale_Win * x_scale)
    reservoir_scale = (scale_Wr * threshold_scale)

    def compute_integer_thresholds(scale):
        return np.int32(-1 / scale), np.int64(1 / scale)

    a_scaled, b_scaled = compute_integer_thresholds(input_scale)
    c_scaled, d_scaled = compute_integer_thresholds(reservoir_scale)

    def piecewise_linear_hard_tanh_integer(x, a_scaled, b_scaled, div_scale):
        x = np.clip(x, a_scaled, b_scaled)
        x = x + b_scaled
        return (x / div_scale).astype(np.int64)

    div_scale = 2 ** bit_width

    def forward2(node: Node, x: np.ndarray) -> np.ndarray:
        state = node.state().astype(np.int64).reshape(1, N)
        r = state @ node.Wr.astype(np.int64)
        s = x @ node.Win.astype(np.int64).T
        s = s.reshape(1, N)
        out_r = piecewise_linear_hard_tanh_integer(s, a_scaled, b_scaled, div_scale)
        out_s = piecewise_linear_hard_tanh_integer(r, c_scaled, d_scaled, div_scale)
        return out_r + out_s + node.Bias.reshape(1, N)

    def initialize(node: Node, x: np.ndarray = None, y: np.ndarray = None):
        if x is not None:
            node.set_input_dim(x.shape[1])
            node.set_output_dim(N)
            node.set_param("Wr", int_Wr)
            node.set_param("Win", int_Win)
            node.set_param("Bias", int_bias)

    class CustomNode(Node):
        def __init__(self, name=None):
            super().__init__(
                forward=forward2,
                initializer=initialize,
                params={"Wr": None, "Win": None, "Bias": None},
                hypers={},
                name=name
            )

    node = CustomNode(name=f"quant_reservoir_N{N}_b{bit_width}")
    esn_model_PTQ = node >> readout

    Quantized_States = node.run(int_x[:train_len].astype(np.float64)) * threshold_scale
    readout.fit(Quantized_States, X[1:train_len + 1], warmup=1000)

    Quantized_States_test = node.run(int_x[train_len+1:-1].astype(np.float64)) * threshold_scale
    Y_pred_PTQ = readout.run(Quantized_States_test)

    # Evaluation
    a="R\u00B2"

    Y_true = X[train_len + 2:]
    return {
        "N": N,
        "bits": bit_width,
        "RMSE": rmse(Y_true, Y_pred_PTQ),
        "NRMSE": nrmse(Y_true, Y_pred_PTQ),
        "R\u00B2": rsquare(Y_true, Y_pred_PTQ)
    }

# %%
def run_esn_float(N):
    from reservoirpy.datasets import multiscroll
    from reservoirpy.nodes import Reservoir, Ridge
    from reservoirpy.observables import rmse, rsquare, nrmse
    import numpy as np

    # Prepare Lorenz dataset
    X = multiscroll(10000)
    X = 2 * (X - X.min()) / (X.max() - X.min()) - 1

    train_len = 5000

    reservoir = Reservoir(N, lr=1, sr=0.9, input_connectivity=0.9, rc_connectivity=0.1, input_scaling=1)
    readout = Ridge(ridge=1e-2)
    esn_model = reservoir >> readout
    esn_model = esn_model.fit(X[:train_len], X[1:train_len + 1], warmup=1000)

    Y_pred = esn_model.run(X[train_len:-1])
    Y_true = X[train_len + 1:]

    return {
        "N": N,
        "bits": "FP",
        "RMSE": rmse(Y_true, Y_pred),
        "NRMSE": nrmse(Y_true, Y_pred),
        "R\u00B2": rsquare(Y_true, Y_pred)
    }

# %%
# Define parameter sets
N_list = [50,100, 150, 200, 250, 300, 350, 400, 450, 500]
bit_width_list = [4, 6, 8,16]

results = []

# Step 1: Run float (baseline) for each N
for N in N_list:
    print(f"Running float (FP32) evaluation for N={N}...")
    float_result = run_esn_float(N)
    results.append(float_result)

# Step 2: Run quantized evaluations
for N in N_list:
    for bits in bit_width_list:
        print(f"Running quantized evaluation for N={N}, bit_width={bits}...")
        quant_result = run_esn_quantization(N, bits)
        results.append(quant_result)

# Step 3: Create DataFrame and save
import pandas as pd

df_results = pd.DataFrame(results)
print(df_results)

# Optional: Save to CSV
df_results.to_csv("quantized_and_float_esn_results.csv", index=False)
# Out:
# Running float (FP32) evaluation for N=50...
# Running Model-0: 5000it [00:00, 18510.77it/s]?, ?it/s]
# Running Model-0: 100%|██████████| 1/1 [00:00<00:00,  3.67it/s]
# Fitting node Ridge-0...
# Running Model-0: 4999it [00:00, 17946.79it/s]
# Running float (FP32) evaluation for N=100...
# Running Model-1: 5000it [00:00, 18324.73it/s]?, ?it/s]
# Running Model-1: 100%|██████████| 1/1 [00:00<00:00,  3.61it/s]
# Fitting node Ridge-1...
# Running Model-1: 4999it [00:00, 18233.68it/s]
# Running float (FP32) evaluation for N=150...
# Running Model-2: 5000it [00:00, 17648.06it/s]?, ?it/s]
# Running Model-2: 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]
# Fitting node Ridge-2...
# Running Model-2: 4999it [00:00, 17811.20it/s]
# Running float (FP32) evaluation for N=200...
# Running Model-3: 5000it [00:00, 17204.92it/s]?, ?it/s]
# Running Model-3: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# Fitting node Ridge-3...
# Running Model-3: 4999it [00:00, 16908.07it/s]
# Running float (FP32) evaluation for N=250...
# Running Model-4: 5000it [00:00, 17043.34it/s]?, ?it/s]
# Running Model-4: 100%|██████████| 1/1 [00:00<00:00,  3.35it/s]
# Fitting node Ridge-4...
# Running Model-4: 4999it [00:00, 16591.05it/s]
# Running float (FP32) evaluation for N=300...
# Running Model-5: 5000it [00:00, 15718.91it/s]?, ?it/s]
# Running Model-5: 100%|██████████| 1/1 [00:00<00:00,  2.82it/s]
# Fitting node Ridge-5...
# Running Model-5: 4999it [00:00, 16458.52it/s]
# Running float (FP32) evaluation for N=350...
# Running Model-6: 5000it [00:00, 15268.42it/s]?, ?it/s]
# Running Model-6: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Fitting node Ridge-6...
# Running Model-6: 4999it [00:00, 15019.96it/s]
# Running float (FP32) evaluation for N=400...
# Running Model-7: 5000it [00:00, 15294.53it/s]?, ?it/s]
# Running Model-7: 100%|██████████| 1/1 [00:00<00:00,  3.00it/s]
# Fitting node Ridge-7...
# Running Model-7: 4999it [00:00, 15657.48it/s]
# Running float (FP32) evaluation for N=450...
# Running Model-8: 5000it [00:00, 15137.95it/s]?, ?it/s]
# Running Model-8: 100%|██████████| 1/1 [00:00<00:00,  2.96it/s]
# Fitting node Ridge-8...
# Running Model-8: 4999it [00:00, 15382.97it/s]
# Running float (FP32) evaluation for N=500...
# Running Model-9: 5000it [00:00, 14897.22it/s]?, ?it/s]
# Running Model-9: 100%|██████████| 1/1 [00:00<00:00,  2.91it/s]
# Fitting node Ridge-9...
# Running Model-9: 4999it [00:00, 14857.07it/s]
# Running quantized evaluation for N=50, bit_width=4...
# Running Model-10: 5000it [00:00, 18559.46it/s]?, ?it/s]
# Running Model-10: 100%|██████████| 1/1 [00:00<00:00,  3.68it/s]
# /home/atousa/.local/lib/python3.10/site-packages/torch/_tensor.py:1644: UserWarning: Named tensors and all their associated APIs are an experimental feature and subject to change. Please do not use them for anything important until they are released as stable. (Triggered internally at /pytorch/c10/core/TensorImpl.h:1935.)
#   return super().rename(names)
# Fitting node Ridge-10...
# Running quant_reservoir_N50_b4: 100%|██████████| 5000/5000 [00:00<00:00, 51142.56it/s]
# Running quant_reservoir_N50_b4: 100%|██████████| 4998/4998 [00:00<00:00, 53085.33it/s]
# Running Ridge-10: 100%|██████████| 4998/4998 [00:00<00:00, 143963.71it/s]
# Running quantized evaluation for N=50, bit_width=6...
# Running Model-12: 5000it [00:00, 16943.21it/s]?, ?it/s]
# Running Model-12: 100%|██████████| 1/1 [00:00<00:00,  3.36it/s]
# Fitting node Ridge-11...
# Running quant_reservoir_N50_b6: 100%|██████████| 5000/5000 [00:00<00:00, 49978.84it/s]
# Running quant_reservoir_N50_b6: 100%|██████████| 4998/4998 [00:00<00:00, 46116.50it/s]
# Running Ridge-11: 100%|██████████| 4998/4998 [00:00<00:00, 139865.17it/s]
# Running quantized evaluation for N=50, bit_width=8...
# Running Model-14: 5000it [00:00, 18342.06it/s]?, ?it/s]
# Running Model-14: 100%|██████████| 1/1 [00:00<00:00,  3.63it/s]
# Fitting node Ridge-12...
# Running quant_reservoir_N50_b8: 100%|██████████| 5000/5000 [00:00<00:00, 50499.71it/s]
# Running quant_reservoir_N50_b8: 100%|██████████| 4998/4998 [00:00<00:00, 48787.32it/s]
# Running Ridge-12: 100%|██████████| 4998/4998 [00:00<00:00, 144162.70it/s]
# Running quantized evaluation for N=50, bit_width=16...
# Running Model-16: 5000it [00:00, 18358.64it/s]?, ?it/s]
# Running Model-16: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
# Fitting node Ridge-13...
# Running quant_reservoir_N50_b16: 100%|██████████| 5000/5000 [00:00<00:00, 46883.01it/s]
# Running quant_reservoir_N50_b16: 100%|██████████| 4998/4998 [00:00<00:00, 48051.48it/s]
# Running Ridge-13: 100%|██████████| 4998/4998 [00:00<00:00, 141799.91it/s]
# Running quantized evaluation for N=100, bit_width=4...
# Running Model-18: 5000it [00:00, 18094.20it/s]?, ?it/s]
# Running Model-18: 100%|██████████| 1/1 [00:00<00:00,  3.58it/s]
# Fitting node Ridge-14...
# Running quant_reservoir_N100_b4: 100%|██████████| 5000/5000 [00:00<00:00, 39499.82it/s]
# Running quant_reservoir_N100_b4: 100%|██████████| 4998/4998 [00:00<00:00, 35063.55it/s]
# Running Ridge-14: 100%|██████████| 4998/4998 [00:00<00:00, 140148.49it/s]
# Running quantized evaluation for N=100, bit_width=6...
# Running Model-20: 5000it [00:00, 17743.27it/s]?, ?it/s]
# Running Model-20: 100%|██████████| 1/1 [00:00<00:00,  3.51it/s]
# Fitting node Ridge-15...
# Running quant_reservoir_N100_b6: 100%|██████████| 5000/5000 [00:00<00:00, 37451.48it/s]
# Running quant_reservoir_N100_b6: 100%|██████████| 4998/4998 [00:00<00:00, 40900.00it/s]
# Running Ridge-15: 100%|██████████| 4998/4998 [00:00<00:00, 121218.31it/s]
# Running quantized evaluation for N=100, bit_width=8...
# Running Model-22: 5000it [00:00, 18025.15it/s]?, ?it/s]
# Running Model-22: 100%|██████████| 1/1 [00:00<00:00,  3.57it/s]
# Fitting node Ridge-16...
# Running quant_reservoir_N100_b8: 100%|██████████| 5000/5000 [00:00<00:00, 39463.84it/s]
# Running quant_reservoir_N100_b8: 100%|██████████| 4998/4998 [00:00<00:00, 42805.49it/s]
# Running Ridge-16: 100%|██████████| 4998/4998 [00:00<00:00, 136572.08it/s]
# Running quantized evaluation for N=100, bit_width=16...
# Running Model-24: 5000it [00:00, 18460.76it/s]?, ?it/s]
# Running Model-24: 100%|██████████| 1/1 [00:00<00:00,  3.64it/s]
# /tmp/ipykernel_2504228/307457933.py:44: RuntimeWarning: invalid value encountered in cast
#   return np.int32(-1 / scale), np.int64(1 / scale)
# Fitting node Ridge-17...
# Running quant_reservoir_N100_b16: 100%|██████████| 5000/5000 [00:00<00:00, 40577.53it/s]
# Running quant_reservoir_N100_b16: 100%|██████████| 4998/4998 [00:00<00:00, 41641.85it/s]
# Running Ridge-17: 100%|██████████| 4998/4998 [00:00<00:00, 139222.38it/s]
# Running quantized evaluation for N=150, bit_width=4...
# Running Model-26: 5000it [00:00, 18006.92it/s]?, ?it/s]
# Running Model-26: 100%|██████████| 1/1 [00:00<00:00,  3.56it/s]
# Fitting node Ridge-18...
# Running quant_reservoir_N150_b4: 100%|██████████| 5000/5000 [00:00<00:00, 32340.00it/s]
# Running quant_reservoir_N150_b4: 100%|██████████| 4998/4998 [00:00<00:00, 31683.64it/s]
# Running Ridge-18: 100%|██████████| 4998/4998 [00:00<00:00, 112156.29it/s]
# Running quantized evaluation for N=150, bit_width=6...
# Running Model-28: 5000it [00:00, 17976.26it/s]?, ?it/s]
# Running Model-28: 100%|██████████| 1/1 [00:00<00:00,  3.54it/s]
# Fitting node Ridge-19...
# Running quant_reservoir_N150_b6: 100%|██████████| 5000/5000 [00:00<00:00, 32475.22it/s]
# Running quant_reservoir_N150_b6: 100%|██████████| 4998/4998 [00:00<00:00, 31643.42it/s]
# Running Ridge-19: 100%|██████████| 4998/4998 [00:00<00:00, 139768.19it/s]
# Running quantized evaluation for N=150, bit_width=8...
# Running Model-30: 5000it [00:00, 17860.13it/s]?, ?it/s]
# Running Model-30: 100%|██████████| 1/1 [00:00<00:00,  3.52it/s]
# Fitting node Ridge-20...
# Running quant_reservoir_N150_b8: 100%|██████████| 5000/5000 [00:00<00:00, 31171.95it/s]
# Running quant_reservoir_N150_b8: 100%|██████████| 4998/4998 [00:00<00:00, 31501.15it/s]
# Running Ridge-20: 100%|██████████| 4998/4998 [00:00<00:00, 140645.90it/s]
# Running quantized evaluation for N=150, bit_width=16...
# Running Model-32: 5000it [00:00, 17408.07it/s]?, ?it/s]
# Running Model-32: 100%|██████████| 1/1 [00:00<00:00,  3.44it/s]
# Fitting node Ridge-21...
# Running quant_reservoir_N150_b16: 100%|██████████| 5000/5000 [00:00<00:00, 32650.20it/s]
# Running quant_reservoir_N150_b16: 100%|██████████| 4998/4998 [00:00<00:00, 32576.28it/s]
# Running Ridge-21: 100%|██████████| 4998/4998 [00:00<00:00, 139034.01it/s]
# Running quantized evaluation for N=200, bit_width=4...
# Running Model-34: 5000it [00:00, 17365.24it/s]?, ?it/s]
# Running Model-34: 100%|██████████| 1/1 [00:00<00:00,  3.43it/s]
# Fitting node Ridge-22...
# Running quant_reservoir_N200_b4: 100%|██████████| 5000/5000 [00:00<00:00, 24549.00it/s]
# Running quant_reservoir_N200_b4: 100%|██████████| 4998/4998 [00:00<00:00, 24979.51it/s]
# Running Ridge-22: 100%|██████████| 4998/4998 [00:00<00:00, 138461.90it/s]
# Running quantized evaluation for N=200, bit_width=6...
# Running Model-36: 5000it [00:00, 17380.40it/s]?, ?it/s]
# Running Model-36: 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
# Fitting node Ridge-23...
# Running quant_reservoir_N200_b6: 100%|██████████| 5000/5000 [00:00<00:00, 24015.15it/s]
# Running quant_reservoir_N200_b6: 100%|██████████| 4998/4998 [00:00<00:00, 24462.18it/s]
# Running Ridge-23: 100%|██████████| 4998/4998 [00:00<00:00, 136422.77it/s]
# Running quantized evaluation for N=200, bit_width=8...
# Running Model-38: 5000it [00:00, 17352.73it/s]?, ?it/s]
# Running Model-38: 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
# Fitting node Ridge-24...
# Running quant_reservoir_N200_b8: 100%|██████████| 5000/5000 [00:00<00:00, 25281.88it/s]
# Running quant_reservoir_N200_b8: 100%|██████████| 4998/4998 [00:00<00:00, 24452.25it/s]
# Running Ridge-24: 100%|██████████| 4998/4998 [00:00<00:00, 139691.81it/s]
# Running quantized evaluation for N=200, bit_width=16...
# Running Model-40: 5000it [00:00, 17612.13it/s]?, ?it/s]
# Running Model-40: 100%|██████████| 1/1 [00:00<00:00,  3.48it/s]
# Fitting node Ridge-25...
# Running quant_reservoir_N200_b16: 100%|██████████| 5000/5000 [00:00<00:00, 25648.81it/s]
# Running quant_reservoir_N200_b16: 100%|██████████| 4998/4998 [00:00<00:00, 25471.82it/s]
# Running Ridge-25: 100%|██████████| 4998/4998 [00:00<00:00, 138535.10it/s]
# Running quantized evaluation for N=250, bit_width=4...
# Running Model-42: 5000it [00:00, 17415.88it/s]?, ?it/s]
# Running Model-42: 100%|██████████| 1/1 [00:00<00:00,  3.42it/s]
# Fitting node Ridge-26...
# Running quant_reservoir_N250_b4: 100%|██████████| 5000/5000 [00:00<00:00, 18439.58it/s]
# Running quant_reservoir_N250_b4: 100%|██████████| 4998/4998 [00:00<00:00, 18776.28it/s]
# Running Ridge-26: 100%|██████████| 4998/4998 [00:00<00:00, 133486.57it/s]
# Running quantized evaluation for N=250, bit_width=6...
# Running Model-44: 5000it [00:00, 16399.63it/s]?, ?it/s]
# Running Model-44: 100%|██████████| 1/1 [00:00<00:00,  3.22it/s]
# Fitting node Ridge-27...
# Running quant_reservoir_N250_b6: 100%|██████████| 5000/5000 [00:00<00:00, 19222.34it/s]
# Running quant_reservoir_N250_b6: 100%|██████████| 4998/4998 [00:00<00:00, 18971.66it/s]
# Running Ridge-27: 100%|██████████| 4998/4998 [00:00<00:00, 135945.91it/s]
# Running quantized evaluation for N=250, bit_width=8...
# Running Model-46: 5000it [00:00, 17236.12it/s]?, ?it/s]
# Running Model-46: 100%|██████████| 1/1 [00:00<00:00,  3.39it/s]
# Fitting node Ridge-28...
# Running quant_reservoir_N250_b8: 100%|██████████| 5000/5000 [00:00<00:00, 18924.51it/s]
# Running quant_reservoir_N250_b8: 100%|██████████| 4998/4998 [00:00<00:00, 19177.53it/s]
# Running Ridge-28: 100%|██████████| 4998/4998 [00:00<00:00, 135771.58it/s]
# Running quantized evaluation for N=250, bit_width=16...
# Running Model-48: 5000it [00:00, 16944.64it/s]?, ?it/s]
# Running Model-48: 100%|██████████| 1/1 [00:00<00:00,  3.33it/s]
# Fitting node Ridge-29...
# Running quant_reservoir_N250_b16: 100%|██████████| 5000/5000 [00:00<00:00, 18731.01it/s]
# Running quant_reservoir_N250_b16: 100%|██████████| 4998/4998 [00:00<00:00, 18800.44it/s]
# Running Ridge-29: 100%|██████████| 4998/4998 [00:00<00:00, 139662.03it/s]
# Running quantized evaluation for N=300, bit_width=4...
# Running Model-50: 5000it [00:00, 16742.43it/s]?, ?it/s]
# Running Model-50: 100%|██████████| 1/1 [00:00<00:00,  3.28it/s]
# Fitting node Ridge-30...
# Running quant_reservoir_N300_b4: 100%|██████████| 5000/5000 [00:00<00:00, 14540.48it/s]
# Running quant_reservoir_N300_b4: 100%|██████████| 4998/4998 [00:00<00:00, 14227.16it/s]
# Running Ridge-30: 100%|██████████| 4998/4998 [00:00<00:00, 137962.54it/s]
# Running quantized evaluation for N=300, bit_width=6...
# Running Model-52: 5000it [00:00, 16548.14it/s]?, ?it/s]
# Running Model-52: 100%|██████████| 1/1 [00:00<00:00,  3.26it/s]
# Fitting node Ridge-31...
# Running quant_reservoir_N300_b6: 100%|██████████| 5000/5000 [00:00<00:00, 14053.32it/s]
# Running quant_reservoir_N300_b6: 100%|██████████| 4998/4998 [00:00<00:00, 14871.49it/s]
# Running Ridge-31: 100%|██████████| 4998/4998 [00:00<00:00, 137857.29it/s]
# Running quantized evaluation for N=300, bit_width=8...
# Running Model-54: 5000it [00:00, 16572.30it/s]?, ?it/s]
# Running Model-54: 100%|██████████| 1/1 [00:00<00:00,  3.25it/s]
# Fitting node Ridge-32...
# Running quant_reservoir_N300_b8: 100%|██████████| 5000/5000 [00:00<00:00, 14816.04it/s]
# Running quant_reservoir_N300_b8: 100%|██████████| 4998/4998 [00:00<00:00, 14420.69it/s]
# Running Ridge-32: 100%|██████████| 4998/4998 [00:00<00:00, 133443.23it/s]
# Running quantized evaluation for N=300, bit_width=16...
# Running Model-56: 5000it [00:00, 16425.44it/s]?, ?it/s]
# Running Model-56: 100%|██████████| 1/1 [00:00<00:00,  3.23it/s]
# Fitting node Ridge-33...
# Running quant_reservoir_N300_b16: 100%|██████████| 5000/5000 [00:00<00:00, 14457.52it/s]
# Running quant_reservoir_N300_b16: 100%|██████████| 4998/4998 [00:00<00:00, 14886.20it/s]
# Running Ridge-33: 100%|██████████| 4998/4998 [00:00<00:00, 136679.82it/s]
# Running quantized evaluation for N=350, bit_width=4...
# Running Model-58: 5000it [00:00, 16360.02it/s]?, ?it/s]
# Running Model-58: 100%|██████████| 1/1 [00:00<00:00,  3.21it/s]
# Fitting node Ridge-34...
# Running quant_reservoir_N350_b4: 100%|██████████| 5000/5000 [00:00<00:00, 10975.24it/s]
# Running quant_reservoir_N350_b4: 100%|██████████| 4998/4998 [00:00<00:00, 11415.44it/s]
# Running Ridge-34: 100%|██████████| 4998/4998 [00:00<00:00, 136211.79it/s]
# Running quantized evaluation for N=350, bit_width=6...
# Running Model-60: 5000it [00:00, 16356.54it/s]?, ?it/s]
# Running Model-60: 100%|██████████| 1/1 [00:00<00:00,  3.08it/s]
# Fitting node Ridge-35...
# Running quant_reservoir_N350_b6: 100%|██████████| 5000/5000 [00:00<00:00, 11054.95it/s]
# Running quant_reservoir_N350_b6: 100%|██████████| 4998/4998 [00:00<00:00, 10781.96it/s]
# Running Ridge-35: 100%|██████████| 4998/4998 [00:00<00:00, 120833.32it/s]
# Running quantized evaluation for N=350, bit_width=8...
# Running Model-62: 5000it [00:00, 16149.90it/s]?, ?it/s]
# Running Model-62: 100%|██████████| 1/1 [00:00<00:00,  3.17it/s]
# Fitting node Ridge-36...
# Running quant_reservoir_N350_b8: 100%|██████████| 5000/5000 [00:00<00:00, 10864.72it/s]
# Running quant_reservoir_N350_b8: 100%|██████████| 4998/4998 [00:00<00:00, 11517.16it/s]
# Running Ridge-36: 100%|██████████| 4998/4998 [00:00<00:00, 133521.43it/s]
# Running quantized evaluation for N=350, bit_width=16...
# Running Model-64: 5000it [00:00, 16250.66it/s]?, ?it/s]
# Running Model-64: 100%|██████████| 1/1 [00:00<00:00,  3.18it/s]
# Fitting node Ridge-37...
# Running quant_reservoir_N350_b16: 100%|██████████| 5000/5000 [00:00<00:00, 10751.25it/s]
# Running quant_reservoir_N350_b16: 100%|██████████| 4998/4998 [00:00<00:00, 10964.94it/s]
# Running Ridge-37: 100%|██████████| 4998/4998 [00:00<00:00, 137618.37it/s]
# Running quantized evaluation for N=400, bit_width=4...
# Running Model-66: 5000it [00:00, 15671.86it/s]?, ?it/s]
# Running Model-66: 100%|██████████| 1/1 [00:00<00:00,  3.07it/s]
# Fitting node Ridge-38...
# Running quant_reservoir_N400_b4: 100%|██████████| 5000/5000 [00:00<00:00, 8155.77it/s]
# Running quant_reservoir_N400_b4: 100%|██████████| 4998/4998 [00:00<00:00, 7971.47it/s]
# Running Ridge-38: 100%|██████████| 4998/4998 [00:00<00:00, 134031.08it/s]
# Running quantized evaluation for N=400, bit_width=6...
# Running Model-68: 5000it [00:00, 15886.94it/s]?, ?it/s]
# Running Model-68: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Fitting node Ridge-39...
# Running quant_reservoir_N400_b6: 100%|██████████| 5000/5000 [00:00<00:00, 7826.91it/s]
# Running quant_reservoir_N400_b6: 100%|██████████| 4998/4998 [00:00<00:00, 7900.63it/s]
# Running Ridge-39: 100%|██████████| 4998/4998 [00:00<00:00, 135204.14it/s]
# Running quantized evaluation for N=400, bit_width=8...
# Running Model-70: 5000it [00:00, 15910.19it/s]?, ?it/s]
# Running Model-70: 100%|██████████| 1/1 [00:00<00:00,  3.11it/s]
# Fitting node Ridge-40...
# Running quant_reservoir_N400_b8: 100%|██████████| 5000/5000 [00:00<00:00, 7953.28it/s]
# Running quant_reservoir_N400_b8: 100%|██████████| 4998/4998 [00:00<00:00, 7885.34it/s]
# Running Ridge-40: 100%|██████████| 4998/4998 [00:00<00:00, 132456.73it/s]
# Running quantized evaluation for N=400, bit_width=16...
# Running Model-72: 5000it [00:00, 15424.31it/s]?, ?it/s]
# Running Model-72: 100%|██████████| 1/1 [00:00<00:00,  3.02it/s]
# Fitting node Ridge-41...
# Running quant_reservoir_N400_b16: 100%|██████████| 5000/5000 [00:00<00:00, 7908.15it/s]
# Running quant_reservoir_N400_b16: 100%|██████████| 4998/4998 [00:00<00:00, 7963.34it/s]
# Running Ridge-41: 100%|██████████| 4998/4998 [00:00<00:00, 123539.27it/s]
# Running quantized evaluation for N=450, bit_width=4...
# Running Model-74: 5000it [00:00, 15531.62it/s]?, ?it/s]
# Running Model-74: 100%|██████████| 1/1 [00:00<00:00,  3.03it/s]
# Fitting node Ridge-42...
# Running quant_reservoir_N450_b4: 100%|██████████| 5000/5000 [00:00<00:00, 6417.18it/s]
# Running quant_reservoir_N450_b4: 100%|██████████| 4998/4998 [00:00<00:00, 6381.82it/s]
# Running Ridge-42: 100%|██████████| 4998/4998 [00:00<00:00, 135746.08it/s]
# Running quantized evaluation for N=450, bit_width=6...
# Running Model-76: 5000it [00:00, 15198.11it/s]?, ?it/s]
# Running Model-76: 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
# Fitting node Ridge-43...
# Running quant_reservoir_N450_b6: 100%|██████████| 5000/5000 [00:00<00:00, 6339.46it/s]
# Running quant_reservoir_N450_b6: 100%|██████████| 4998/4998 [00:00<00:00, 6359.89it/s]
# Running Ridge-43: 100%|██████████| 4998/4998 [00:00<00:00, 133513.78it/s]
# Running quantized evaluation for N=450, bit_width=8...
# Running Model-78: 5000it [00:00, 15239.45it/s]?, ?it/s]
# Running Model-78: 100%|██████████| 1/1 [00:00<00:00,  2.98it/s]
# Fitting node Ridge-44...
# Running quant_reservoir_N450_b8: 100%|██████████| 5000/5000 [00:00<00:00, 6347.87it/s]
# Running quant_reservoir_N450_b8: 100%|██████████| 4998/4998 [00:00<00:00, 6268.52it/s]
# Running Ridge-44: 100%|██████████| 4998/4998 [00:00<00:00, 134180.36it/s]
# Running quantized evaluation for N=450, bit_width=16...
# Running Model-80: 5000it [00:00, 15238.94it/s]?, ?it/s]
# Running Model-80: 100%|██████████| 1/1 [00:00<00:00,  2.97it/s]
# Fitting node Ridge-45...
# Running quant_reservoir_N450_b16: 100%|██████████| 5000/5000 [00:00<00:00, 6682.49it/s]
# Running quant_reservoir_N450_b16: 100%|██████████| 4998/4998 [00:00<00:00, 6391.86it/s]
# Running Ridge-45: 100%|██████████| 4998/4998 [00:00<00:00, 134388.52it/s]
# Running quantized evaluation for N=500, bit_width=4...
# Running Model-82: 5000it [00:00, 15130.94it/s]?, ?it/s]
# Running Model-82: 100%|██████████| 1/1 [00:00<00:00,  2.92it/s]
# Fitting node Ridge-46...
# Running quant_reservoir_N500_b4: 100%|██████████| 5000/5000 [00:00<00:00, 5469.92it/s]
# Running quant_reservoir_N500_b4: 100%|██████████| 4998/4998 [00:00<00:00, 5463.71it/s]
# Running Ridge-46: 100%|██████████| 4998/4998 [00:00<00:00, 120145.64it/s]
# Running quantized evaluation for N=500, bit_width=6...
# Running Model-84: 5000it [00:00, 14574.32it/s]?, ?it/s]
# Running Model-84: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
# Fitting node Ridge-47...
# Running quant_reservoir_N500_b6: 100%|██████████| 5000/5000 [00:00<00:00, 5331.76it/s]
# Running quant_reservoir_N500_b6: 100%|██████████| 4998/4998 [00:00<00:00, 5335.81it/s]
# Running Ridge-47: 100%|██████████| 4998/4998 [00:00<00:00, 131073.64it/s]
# Running quantized evaluation for N=500, bit_width=8...
# Running Model-86: 5000it [00:00, 14811.38it/s]?, ?it/s]
# Running Model-86: 100%|██████████| 1/1 [00:00<00:00,  2.88it/s]
# Fitting node Ridge-48...
# Running quant_reservoir_N500_b8: 100%|██████████| 5000/5000 [00:00<00:00, 5307.39it/s]
# Running quant_reservoir_N500_b8: 100%|██████████| 4998/4998 [00:00<00:00, 5356.96it/s]
# Running Ridge-48: 100%|██████████| 4998/4998 [00:00<00:00, 134488.53it/s]
# Running quantized evaluation for N=500, bit_width=16...
# Running Model-88: 5000it [00:00, 14627.72it/s]?, ?it/s]
# Running Model-88: 100%|██████████| 1/1 [00:00<00:00,  2.84it/s]
# Fitting node Ridge-49...
# Running quant_reservoir_N500_b16: 100%|██████████| 5000/5000 [00:00<00:00, 5618.39it/s]
# Running quant_reservoir_N500_b16: 100%|██████████| 4998/4998 [00:00<00:00, 5279.03it/s]
# Running Ridge-49: 100%|██████████| 4998/4998 [00:00<00:00, 132080.34it/s]
#       N bits      RMSE     NRMSE        R²
# 0    50   FP  0.000494  0.000286  0.999998
# 1   100   FP  0.000321  0.000186  0.999999
# 2   150   FP  0.000285  0.000165  0.999999
# 3   200   FP  0.000274  0.000159  0.999999
# 4   250   FP  0.000261  0.000152  0.999999
# 5   300   FP  0.000264  0.000153  0.999999
# 6   350   FP  0.000254  0.000148  0.999999
# 7   400   FP  0.000252  0.000146  0.999999
# 8   450   FP  0.000244  0.000141  0.999999
# 9   500   FP  0.000234  0.000136  1.000000
# 10   50    4  0.037968  0.022023  0.986936
# 11   50    6  0.013668  0.007928  0.998307
# 12   50    8  0.005315  0.003083  0.999744
# 13   50   16  0.002484  0.001441  0.999944
# 14  100    4  0.034784  0.020176  0.989035
# 15  100    6  0.010351  0.006004  0.999029
# 16  100    8  0.004414  0.002561  0.999823
# 17  100   16  0.001378  0.000799  0.999983
# 18  150    4  0.032538  0.018873  0.990406
# 19  150    6  0.010272  0.005958  0.999044
# 20  150    8  0.003295  0.001911  0.999902
# 21  150   16  0.001147  0.000665  0.999988
# 22  200    4  0.031055  0.018013  0.991260
# 23  200    6  0.009233  0.005355  0.999228
# 24  200    8  0.002924  0.001696  0.999923
# 25  200   16  0.000828  0.000480  0.999994
# 26  250    4  0.030346  0.017602  0.991655
# 27  250    6  0.008715  0.005055  0.999312
# 28  250    8  0.002712  0.001573  0.999933
# 29  250   16  0.000752  0.000436  0.999995
# 30  300    4  0.030730  0.017825  0.991442
# 31  300    6  0.007807  0.004528  0.999448
# 32  300    8  0.002759  0.001600  0.999931
# 33  300   16  0.000684  0.000397  0.999996
# 34  350    4  0.028997  0.016819  0.992381
# 35  350    6  0.007658  0.004442  0.999469
# 36  350    8  0.002677  0.001552  0.999935
# 37  350   16  0.000676  0.000392  0.999996
# 38  400    4  0.027362  0.015871  0.993215
# 39  400    6  0.007564  0.004388  0.999481
# 40  400    8  0.002248  0.001304  0.999954
# 41  400   16  0.000644  0.000374  0.999996
# 42  450    4  0.027848  0.016153  0.992972
# 43  450    6  0.007146  0.004145  0.999537
# 44  450    8  0.002319  0.001345  0.999951
# 45  450   16  0.000554  0.000321  0.999997
# 46  500    4  0.027485  0.015943  0.993154
# 47  500    6  0.006634  0.003848  0.999601
# 48  500    8  0.002174  0.001261  0.999957
# 49  500   16  0.000578  0.000336  0.999997

# %%
import matplotlib.pyplot as plt

metrics = ['RMSE', 'NRMSE']
fig, axes = plt.subplots(1, 2, figsize=(16, 6))

for i, metric in enumerate(metrics):
    ax = axes[i]
    for bits in ['FP', 4, 6, 8]:
        subset = df_results[df_results['bits'] == bits]
        # only add "-bit" suffix for the numeric entries
        if bits == 'FP':
            label = 'FP'
        else:
            label = f"{bits}-bit"
        ax.plot(subset['N'], subset[metric], marker='o', label=label)

    ax.set_title(f"{metric} vs. Reservoir Size", fontsize=30)
    ax.set_xlabel("Reservoir Size [number of neurons]", fontsize=30)
    ax.set_ylabel(metric, fontsize=30)
    ax.tick_params(axis='both', labelsize=18)
    ax.grid(True)
    ax.legend(fontsize=18)

plt.tight_layout()
plt.savefig("multiscroll.pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
for bits in ['FP', 4, 6, 8]:
    subset = df_results[df_results['bits'] == bits]
    label = 'FP-32' if bits == 'FP' else f"{bits}-bit"
    plt.plot(subset['N'], subset['RMSE'], marker='o', label=label)

plt.xlabel("Reservoir Size [number of neurons]", fontsize=24)
plt.ylabel("RMSE", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.grid(True)
plt.tight_layout()

# Transparent legend and more space from top
plt.legend(fontsize=24, framealpha=0.3, loc='center')

plt.savefig("multiscroll.pdf", bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Define styles
styles = {
    'FP':  dict(color='black',      linestyle='-',  marker='o'),
    4:     dict(color='tab:red',    linestyle='--', marker='s'),
    6:     dict(color='tab:blue',   linestyle='-.', marker='^'),
    8:     dict(color='tab:green',  linestyle=':',  marker='D'),
    16:    dict(color='tab:purple', linestyle=(0, (3, 1, 1, 1)), marker='*')
}

plt.figure(figsize=(10, 6))

for bits in ['FP', 4, 6, 8, 16]:
    subset = df_results[df_results['bits'] == bits]
    label = 'FP-32' if bits == 'FP' else f"{bits}-bit"

    plt.plot(
        subset['N'],
        subset['RMSE'],
        label=label,
        linewidth=2.5,
        markersize=14,          # bigger markers
        markeredgewidth=1.8,    # thicker marker border

        **styles[bits]
    )

plt.xlabel("Reservoir Size [number of neurons]", fontsize=24)
plt.ylabel("RMSE", fontsize=24)
plt.xticks(fontsize=24)
plt.yticks(fontsize=24)
plt.grid(True, alpha=0.3)

plt.tight_layout()
plt.savefig("multiscroll_R.pdf", bbox_inches='tight')
plt.show()

# %%
print("R\u00B2")
# Out:
# R²
